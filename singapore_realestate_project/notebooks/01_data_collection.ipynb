# %% [markdown]
# # Phase 1: Data Collection
#
# Collect real estate data, school/hospital/MRT locations from various sources.

# %%
import sys
sys.path.insert(0, '../scripts')

import pandas as pd
import numpy as np
from data_collection import DataCollector
from config import RAW_DATA_DIR, SINGAPORE_CENTER

print("Data collection module loaded successfully!")

# %% [markdown]
# ## Step 1: Initialize Data Collector

# %%
collector = DataCollector()
print(f"Raw data directory: {RAW_DATA_DIR}")
print(f"Singapore center: {SINGAPORE_CENTER}")

# %% [markdown]
# ## Step 2: Download HDB Data
#
# Download HDB resale transaction data from data.gov.sg

# %%
# TODO: Implement HDB data download
# collector.download_hdb_data()

print("HDB data collection template ready for implementation")

# %% [markdown]
# ## Step 3: Download School Data

# %%
# TODO: Implement school data download
# collector.download_moe_schools()

print("School data collection template ready for implementation")

# %% [markdown]
# ## Step 4: Download Hospital Data

# %%
# TODO: Implement hospital data download
# collector.download_moh_hospitals()

print("Hospital data collection template ready for implementation")

# %% [markdown]
# ## Step 5: Get MRT Station Data

# %%
# TODO: Implement MRT station data collection
# mrt_stations = collector.get_mrt_stations()
# mrt_df = pd.DataFrame(mrt_stations)
# collector.save_raw_data(mrt_df, "mrt_stations.csv")

print("MRT station data collection template ready for implementation")

# %% [markdown]
# ## Step 6: (Optional) Scrape Private Properties
#
# Use Selenium to scrape property portal if needed

# %%
# TODO: Implement web scraping with Selenium
# Example:
# collector.scrape_private_properties("https://www.propertyguru.com.sg/", headless=True)

print("Web scraping template ready for implementation")

# %% [markdown]
# ## Notes
#
# - Data sources priority:
#   1. data.gov.sg - Official government datasets
#   2. Kaggle - Pre-compiled Singapore real estate datasets
#   3. Google Maps API - Location coordinates
#   4. Web scraping (fallback) - Property portals
#
# - Save all raw data to `data/raw/` directory
# - Keep original files untouched
# - Document data sources and collection dates
